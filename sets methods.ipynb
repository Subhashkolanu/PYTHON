# %%
s={112,183,431,440,439,440,786,446,478}
s
# Out:
# {112, 183, 431, 439, 440, 446, 478, 786}

# %%
s=[112,183,431,440,439,440,786]
a=set(s)
a
# Out:
# {112, 183, 431, 439, 440, 786}

# %%
s=(112,183,431,440,439,440,786)
a=set(s)
a
# Out:
# {112, 183, 431, 439, 440, 786}

# %%
d={1:"Bharat",2:"subhash",3:"Venkatesh"}
s=set(d)
s
# Out:
# {1, 2, 3}

# %%
n={112,446,480,440,439,183,431,440,439,440,786}
n
# Out:
# {112, 183, 431, 439, 440, 446, 480, 786}

# %%
cars={"BMW","ASTON MARTIN","BENZ"}
for i in cars:
    print(cars)
# Out:
# {'ASTON MARTIN', 'BMW', 'BENZ'}
# {'ASTON MARTIN', 'BMW', 'BENZ'}
# {'ASTON MARTIN', 'BMW', 'BENZ'}

# %%
cars={"BMW","ASTON MARTIN","BENZ"}
racers={"Max verstappen","Niki lauda"}
cars.update(racers)
cars
# Out:
# {'ASTON MARTIN', 'BENZ', 'BMW', 'Max verstappen', 'Niki lauda'}

# %%
cars={"BMW","ASTON MARTIN","BENZ"}
cars.add("FERARI")
cars
# Out:
# {'ASTON MARTIN', 'BENZ', 'BMW', 'FERARI'}
