# %%
for letter in "SUBHASH":
    if letter == "A":
        break
    print("The current letter is ",letter)
print("The letter is found!")

# %%
s="mississippi"
s.count("s")
# Out:
# 4

# %%
s="bananna"
s.index("n")
# Out:
# 2

# %%
s="apple"
s.startswith("a")
# Out:
# True

# %%
a="Mobile"
a.startswith("e")
# Out:
# False

# %%
a="Mobile"
a.endswith("e")
# Out:
# True

# %%
a="Mobile"
a.endswith("M")
# Out:
# False

# %%
s="xioami is the apple of china"
s.replace('apple of china',"huwaei of hong kong")
# Out:
# 'xioami is the huwaei of hong kong'

# %%
s="python programming language"
s.strip("python")
s="python programming    "
s.strip()

# %%
s="python programming    "
s.strip()

# %%
s="     python programming language"
s.lstrip()

# %%
s="data science with python    "
s.rstrip()
# Out:
# 'data science with python'

# %%
s="is fun"
s.capitalize()
# Out:
# 'Is fun'

# %%
s="consistency is the key"
s.split()
# Out:
# ['consistency', 'is', 'the', 'key']

# %%
s="apple, banana, mango-orange"
s.rsplit()
# Out:
# ['apple,', 'banana,', 'mango-orange']

# %%
words = ["apple", "banana", "mango"]
" * ".join(words)
# Out:
# 'apple * banana * mango'

# %%
greet = "PUSHPA" #positive indexing
print(greet[2])

# %%
greet = "Rajasaab" #negative indexing
print(greet[-6])

# %%
Hero = "ALLU ARJUN" #Slicing
print(Hero[5:10])

# %%
#string comparison
a = 'BHARAT'
b = 'bharat'
print(a==b)

# %%
#string comparison
a = "BHARAT"
b = 'bharat'
print(a==b)

# %%
#string comparision
a = "Bharat"
b = " is a "
c = "GuY"
print(a+b+c)

# %%
#string length
a = "Bharat is a boy"
print(len(a))

# %%
#membership
print('bro' in "bro code")
print('chrome' not in 'opera is the best browser')
