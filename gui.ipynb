# %% [markdown]
# GUI using Tkinter

# %%
import tkinter as s
root=s.Tk()
root.title("First GUI")
root.geometry("1920x1080")
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[2], line 4
#       1 import tkinter as s
#       2 root=s.Tk()
#       3 root.title("First GUI")
# ----> 4 root.geometry("1920*1080")
#       5 root.mainloop()
#
# File c:\Users\kos72\AppData\Local\Python\pythoncore-3.14-64\Lib\tkinter\__init__.py:2253, in Wm.wm_geometry(self, newGeometry)
#    2250 def wm_geometry(self, newGeometry=None):
#    2251     """Set geometry to NEWGEOMETRY of the form =widthxheight+x+y. Return
#    2252     current value if None is given."""
# -> 2253     return self.tk.call('wm', 'geometry', self._w, newGeometry)
#
# TclError: bad geometry specifier "1920*1080"
