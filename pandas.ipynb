# %%
import pandas as s

# %%
l1=s.Series([10,20,30,40,"KSS"])
print(l1)

# %%
l1=s.Series([10,20,30,40])
l1.index

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.values

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.value_counts

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.name="Marks"
l1

# %%
l1

# %%
l1[0:8]

# %%
l1[:4]

# %%
l1.iloc[3]

# %%
cars=s.Series(["AUDI","BENZ","BMW","VOLKSWAGEN"])
cars.name="CARS"
cars

# %%
cost=s.Series([100000,100000,100000,100000])
cost

# %%
cost.index=cars
cost

# %%
cars.index=cost
cars

# %% [markdown]
# Pandas operations

# %%
import pandas as pd

# %%
data={
    "Name":["KB","KSV","KV","KA","KSS"],
    "Age":[18,17,17,18,18],
    "Marks":[99,98,97,99,75]
    }
d=pd.DataFrame(data)
print(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 6
#       2     "Name":["KB","KSV","KV","KA","KSS"],
#       3     "Age":[18,17,17,18,17,18],
#       4     "Marks":[99,98,97,99,94,75]
#       5     }
# ----> 6 d=pd.DataFrame(data)
#       7 print(d)
#
# File c:\Users\kos72\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# File c:\Users\kos72\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File c:\Users\kos72\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File c:\Users\kos72\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\construction.py:643, in _extract_index(data)
#     641 if have_raw_arrays:
#     642     if len(raw_lengths) > 1:
# --> 643         raise ValueError("All arrays must be of the same length")
#     645     if have_dicts:
#     646         raise ValueError(
#     647             "Mixing dicts with non-Series may lead to ambiguous ordering."
#     648         )
#
# ValueError: All arrays must be of the same length
