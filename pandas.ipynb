# %%
import pandas as s

# %%
l1=s.Series([10,20,30,40,"KSS"])
print(l1)
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4    KSS
# dtype: object

# %%
l1=s.Series([10,20,30,40])
l1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.values
# Out:
# array([10, 20, 30, 40, 'KSS'], dtype=object)

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     10
# 1     20
# 2     30
# 3     40
# 4    KSS
# dtype: object>

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.name="Marks"
l1
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4    KSS
# Name: Marks, dtype: object

# %%
l1
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4    KSS
# Name: Marks, dtype: object

# %%
l1[0:8]
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4    KSS
# Name: Marks, dtype: object

# %%
l1[:4]
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: Marks, dtype: object

# %%
l1.iloc[3]
# Out:
# 40

# %%
c=s.Series(["BMW","BENZ","AUDI","TOYOTA"])

# %%
c.iloc[[0,2]]
# Out:
# 0     BMW
# 2    AUDI
# dtype: str

# %%
c.name="CARS"

# %%
c
# Out:
# 0       BMW
# 1      BENZ
# 2      AUDI
# 3    TOYOTA
# Name: CARS, dtype: str

# %%
Cost=[100000,100000,100000,100000]

# %%
c.index=Cost
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 c.index=Cost
#
# NameError: name 'c' is not defined
