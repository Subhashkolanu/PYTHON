# %%
import pandas as s

# %%
l1=s.Series([10,20,30,40,"KSS"])
print(l1)

# %%
l1=s.Series([10,20,30,40])
l1.index

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.values

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.value_counts

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.name="Marks"
l1

# %%
l1

# %%
l1[0:8]

# %%
l1[:4]

# %%
l1.iloc[3]

# %%
cars=s.Series(["AUDI","BENZ","BMW","VOLKSWAGEN"])
cars.name="CARS"
cars

# %%
cost=s.Series([100000,100000,100000,100000])
cost

# %%
cost.index=cars
cost

# %%
cars.index=cost
cars

# %% [markdown]
# Pandas operations

# %%
import pandas as pd

# %%
data={
    "Name":["KB","KSV","KV","KA","KSS"],
    "Age":[18,17,17,18,18],
    "Marks":[99,98,97,99,75]
    }
d=pd.DataFrame(data)
print(d)
# Out:
#   Name  Age  Marks
# 0   KB   18     99
# 1  KSV   17     98
# 2   KV   17     97
# 3   KA   18     99
# 4  KSS   18     75
