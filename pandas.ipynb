# %%
import pandas as s

# %%
l1=s.Series([10,20,30,40,"KSS"])
print(l1)

# %%
l1=s.Series([10,20,30,40])
l1.index

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.values

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.value_counts

# %%
l1=s.Series([10,20,30,40,"KSS"])
l1.name="Marks"
l1

# %%
l1

# %%
l1[0:8]

# %%
l1[:4]

# %%
l1.iloc[3]

# %%
cars=s.Series(["AUDI","BENZ","BMW","Volkswagen"])
cars.name="CARS"
cars
# Out:
# 0          AUDI
# 1          BENZ
# 2           BMW
# 3    Volkswagen
# Name: CARS, dtype: str

# %%
cost=s.Series([100000,100000,100000,100000])
cost
# Out:
# 0    100000
# 1    100000
# 2    100000
# 3    100000
# dtype: int64

# %%
cars.index=cost
cars
# Out:
# 100000          AUDI
# 100000          BENZ
# 100000           BMW
# 100000    Volkswagen
# Name: CARS, dtype: str
