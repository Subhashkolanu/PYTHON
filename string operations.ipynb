# %%
for letter in "SUBHASH":
    if letter == "A":
        break
    print("The current letter is ",letter)
print("The letter is found!")
# Out:
# The current letter is  S
# The current letter is  U
# The current letter is  B
# The current letter is  H
# The letter is found!

# %%
greet = "PUSHPA" #positive indexing
print(greet[2])
# Out:
# S

# %%
greet = "Rajasaab" #negative indexing
print(greet[-6])
# Out:
# j

# %%
Hero = "ALLU ARJUN" #Slicing
print(Hero[5:10])
# Out:
# ARJUN

# %%
#string comparison
a = 'BHARAT'
b = 'bharat'
print(a==b)
# Out:
# False

# %%
#string comparison
a = "BHARAT"
b = 'bharat'
print(a==b)
# Out:
# False

# %%
#string comparision
a = "Bharat"
b = " is a "
c = "GuY"
print(a+b+c)
# Out:
# Bharat is a GuY

# %%
#string length
a = "Bharat is a boy"
print(len(a))
# Out:
# 15

# %%
#membership
print('bro' in "bro code")
print('chrome' not in 'opera is the best browser')
# Out:
# True
# True
