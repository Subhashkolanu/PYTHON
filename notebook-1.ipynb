# %%
print("Hello, Python!")

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print("Ika modaleddama!")

# %%
print("My name is Sai")
print("I am learning Python")

# %%
x = 10.5
print(type(x))

# %%
x = 20
print(type(x))

# %%
x = 15463.5
print(type(x))

# %%
a = 100
b = 600
print(a+b)

# %%
name="subhash"
print(name)

# %%
x=int(input("Enter your age :"))
print(x*2)

# %%
word = "KING"
print(word[2])

# %%
marks = [80, 85, 90, 75]
print(marks[-3])

# %%
marks = [80, 85, 90, 75]
marks.append(100)
marks.remove(90)

# %%
print(marks)

# %%
marks = [80, 85, 90, 75]
print(marks)
marks.pop(2)
print(marks)
print(len(marks))

# %%
data = ["Sai", 18, 85.5, True]
print(data)

# %%
help("keywords")

# %%
print("Hello Python!")

# %%
x=480
print("x = ",x)

# %%
x=input("Enter the value : ")
print("user input =  ",x)

# %%
a = int(input("Enter value of a = "))
print("a = ",a)
b = int(input("enter the value of b = "))
print("b = ",b)
print("Sum of a and b =  ",a+b)

# %%
a = int(input("Enter value of a = "))
print("a = ",a)
b = int(input("enter the value of b = "))
print("b = ",b)
print("div of a and b =  ",a/b)

# %%
a = 100
b = 200
c = 300
print(a,b,c)

# %%
x = 10
y = 10.5
z = "python"
print(type(x))
print(type(y))
print(type(z))

# %%
a = int(input("Enter value of a = "))
print("a = ",a)
b = int(input("enter the value of b = "))
print("b = ",b)
if a==b:
 print("true")
else:
  print("false")

# %%
a = int(input("Enter value of a = "))
print("a = ",a)
b = int(input("enter the value of b = "))
print("b = ",b)
if a!=b:
 print("true")
else:
  print("false")

# %%
for i in range(1,6):
    for j in range(i):
        print("*",end="")
        print()

# %%
x='Krishna'
result=list(x)
print(result)
print(type(x))
print(type(result))

# %%
X=['BMW','AUDI','TOYOTA','FIAT','LEXUS']
print('Length :',len(X))

# %%
lan=['Java','Python','C','C++','c#']
print(lan[4]) #Positive indexing
print(lan[-2]) #Negative indexing

# %%
l=[1,11,111,1111,11111,111111]
print(l[2])
print(l[0:5])
print(l[1::2])
print(l[0::2])

# %%
l1=['a','b','c',[1,2,3],]
print(l1)
l2=l1

# %%
l=[1,11,111,1111,11111,111111]
lan=['Java','Python','C','C++','c#']
z = print(l+lan)
print(len(l))

# %%
a=[11,22,33,44]
print(a*3)

# %%
lan=['Java','Python','C','C++','c#']
print('R' in lan)
print('Java' in lan)

# %%
a=[11,22,33,44,55,66,77,88,99]
print(max(a))
print(min(a))

# %%
a=[1558951,458,969,29678,35983,465984]
print(sum(a))
print(sorted(a))

# %%
l=['Java','Python','C','C++','c#']
x=['BMW','AUDI','TOYOTA','FIAT','LEXUS']
x.append("BENZ")
print(x)

# %%
l=['Java','Python','C','C++','c#']
x=['BMW','AUDI','TOYOTA','FIAT','LEXUS']
l.extend(x)
print(l)

# %%
a=[1,2,3]
a.insert(2,21)
print(a)
a.remove(2)
print(a)

# %%
l=['Java','Python','C','C++','c#']
l.pop(3)

print(l)

# %%
l=['Java','Python','C','C++','c#']
l.clear()
print(l)

# %%
l=['Java','Python','C','C++','c#']
print(l.index("Java"))

# %%
a=[151,11,67,89,6,45,1,11,54,44,66,89,33,88,66,77,11,66,99,]
print(a.count(11))
list.sort(a)
print(a)
a.sort(reverse=True)
print(a)
a.reverse()
print(a)

# %%
a=[178,263,688,399,487,254,226,188,225,484,458,14,116,498]
a.reverse()
print(a)

# %%
c=['BMW','AUDI','TOYOTA','FIAT','LEXUS']
c1=[c[2],c[3],c[1],c[0]]
print(c1)

# %%
a=()
print(a)

# %%
v=('Bike','Car','Truck','Van','Bus','Buldozer')
print(v[0])

# %%
v=('Bike','Car','Truck','Van','Bus','Buldozer')
print(len(v))

# %%
v=('Bike','Car','Truck','Van','Bus','Buldozer')
for vehicle in v:
    print(vehicle)

# %%
v=('Bike','Car','Truck','Van','Bus','Buldozer')
print("Bike" in v)
print("Train" in v)

# %%
print(tuple("Bharat"))

# %%
set={1,2,5,9,7,8}
print(set)
s1={'b','h','a','r','a','t'}
type(s1)

# %%
s2={}
type(s2)

# %%
s3=()
type(s3)

# %%
n="Bharat"
print("Topper {}  wants to learn about format".format(n))
# Out:
# Topper Bharat  wants to learn about format
